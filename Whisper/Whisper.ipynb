# %%
import whisper
import subprocess #if stripping audio from video file
import datetime #to print time of start and end of analysis

# %%
# Choose and load model size
model_size= "small"
base_model = whisper.load_model(model_size)

# %%
#Path to file that needs to be transcribed
#This should be modified to cycle through files in a folder
path = "TestFilm.mov"

# %%
# Strip audio from video file. Not necessary for Whisper, but possible for running other analyses

#subprocess.call(['ffmpeg', '-i', path, 'audio.wav', '-y'])
#path= 'audio.wav'

# %%
print(datetime.datetime.now())
#result = 
base_model.transcribe(path)
#print(result["text"])
#print(datetime.datetime.now())
# Out:
# 2023-02-07 09:18:29.980313
# {'text': ' Innan vi slutar ska berätta att häromveckan kunde vi läsa att Stefan Löfven och Jonas Sjöstet lyckades pricka in sina sommartal exakt samtidigt. Det visar sig vara svårt faktiskt att hänga med i båda samtal samtidigt. Stort tack. Varmt välkomna hit. Alla som har samlats. Det här är ett stort. Jag hoppas att ni har haft en fin sommar. Det har jag haft. Det är många som har klagat på vädret den här sommaren. Det är... Det har varit för kallt i vattnet när man vill bada och det har varit för många myggor runt grillen när man ska grilla. Och de senaste möten. Den ser vi ut över världen och det brukar vi igen. Om skillnaden mellan vänster. Det är det som är lösningen. Det kanske är lite ovanligt att höra mig säga det jag ska säga nu. Men en fullvöxel man borde skjutas. Tack så mycket.',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 9.6,
#    'text': ' Innan vi slutar ska berätta att häromveckan kunde vi läsa att Stefan Löfven och Jonas Sjöstet lyckades pricka in sina sommartal exakt samtidigt.',
#    'tokens': [682,
#     17622,
#     1932,
#     1061,
#     32142,
#     9958,
#     5948,
#     34802,
#     951,
#     6533,
#     298,
#     33676,
#     282,
#     350,
#     13271,
#     1932,
#     8235,
#     5790,
#     951,
#     32158,
#     50123,
#     69,
#     553,
#     3795,
#     34630,
#     318,
#     73,
#     36995,
#     302,
#     17293,
#     547,
#     2977,
#     582,
#     618,
#     64,
#     294,
#     43400,
#     41854,
#     446,
#     304,
#     454,
#     5886,
#     3247,
#     83,
#     327,
#     5828,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36731743325992505,
#    'compression_ratio': 1.4,
#    'no_speech_prob': 0.14746370911598206},
#   {'id': 1,
#    'seek': 0,
#    'start': 9.6,
#    'end': 14.6,
#    'text': ' Det visar sig vara svårt faktiskt att hänga med i båda samtal samtidigt.',
#    'tokens': [4237,
#     1452,
#     289,
#     4556,
#     17234,
#     17342,
#     45287,
#     35988,
#     951,
#     276,
#     9935,
#     64,
#     1205,
#     741,
#     32758,
#     2675,
#     3247,
#     32831,
#     3247,
#     83,
#     327,
#     5828,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36731743325992505,
#    'compression_ratio': 1.4,
#    'no_speech_prob': 0.14746370911598206},
#   {'id': 2,
#    'seek': 0,
#    'start': 21.8,
#    'end': 26.6,
#    'text': ' Stort tack. Varmt välkomna hit. Alla som har samlats.',
#    'tokens': [745,
#     477,
#     9426,
#     13,
#     691,
#     4452,
#     83,
#     22974,
#     20557,
#     629,
#     2045,
#     13,
#     1057,
#     64,
#     3307,
#     2233,
#     3247,
#     75,
#     1720,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.36731743325992505,
#    'compression_ratio': 1.4,
#    'no_speech_prob': 0.14746370911598206},
#   {'id': 3,
#    'seek': 2660,
#    'start': 26.6,
#    'end': 30.8,
#    'text': ' Det här är ett stort. Jag hoppas att ni har haft en fin sommar. Det har jag haft.',
#    'tokens': [4237,
#     6533,
#     3775,
#     5431,
#     342,
#     477,
#     13,
#     9014,
#     3818,
#     20990,
#     951,
#     3867,
#     2233,
#     32329,
#     465,
#     962,
#     41854,
#     289,
#     13,
#     4237,
#     2233,
#     6368,
#     32329,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 4,
#    'seek': 2660,
#    'start': 30.8,
#    'end': 34.6,
#    'text': ' Det är många som har klagat på vädret den här sommaren.',
#    'tokens': [4237,
#     3775,
#     25068,
#     3307,
#     2233,
#     9671,
#     559,
#     267,
#     4170,
#     12099,
#     67,
#     1505,
#     1441,
#     6533,
#     41854,
#     4484,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 5,
#    'seek': 2660,
#    'start': 34.6,
#    'end': 36.6,
#    'text': ' Det är...',
#    'tokens': [4237, 3775, 485],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 6,
#    'seek': 2660,
#    'start': 38.400000000000006,
#    'end': 44.6,
#    'text': ' Det har varit för kallt i vattnet när man vill bada och det har varit för många myggor runt grillen när man ska grilla.',
#    'tokens': [4237,
#     2233,
#     31289,
#     4816,
#     350,
#     336,
#     83,
#     741,
#     371,
#     1591,
#     7129,
#     15457,
#     587,
#     4284,
#     272,
#     1538,
#     3795,
#     1141,
#     2233,
#     31289,
#     4816,
#     25068,
#     452,
#     1615,
#     284,
#     49435,
#     16492,
#     268,
#     15457,
#     587,
#     9958,
#     677,
#     5291,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 7,
#    'seek': 2660,
#    'start': 44.6,
#    'end': 45.6,
#    'text': ' Och de senaste möten.',
#    'tokens': [13128, 368, 3151, 9079, 7667, 1147, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 8,
#    'seek': 2660,
#    'start': 45.6,
#    'end': 49.6,
#    'text': ' Den ser vi ut över världen och det brukar vi igen.',
#    'tokens': [6458,
#     816,
#     1932,
#     2839,
#     23026,
#     28187,
#     35963,
#     3795,
#     1141,
#     48316,
#     289,
#     1932,
#     31305,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 9,
#    'seek': 2660,
#    'start': 51.6,
#    'end': 53.6,
#    'text': ' Om skillnaden mellan vänster.',
#    'tokens': [9757, 5389, 45578, 46494, 371, 4029, 3120, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2350307151452819,
#    'compression_ratio': 1.7593360995850622,
#    'no_speech_prob': 3.218242636648938e-05},
#   {'id': 10,
#    'seek': 5360,
#    'start': 53.6,
#    'end': 60.6,
#    'text': ' Det är det som är lösningen. Det kanske är lite ovanligt att höra mig säga det jag ska säga nu.',
#    'tokens': [4237,
#     3775,
#     1141,
#     3307,
#     3775,
#     287,
#     11310,
#     23137,
#     13,
#     4237,
#     24487,
#     3775,
#     15100,
#     277,
#     9768,
#     16770,
#     951,
#     13531,
#     424,
#     6186,
#     28013,
#     1141,
#     6368,
#     9958,
#     28013,
#     3822,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.19817055188692534,
#    'compression_ratio': 1.2283464566929134,
#    'no_speech_prob': 5.173612407816108e-06},
#   {'id': 11,
#    'seek': 5360,
#    'start': 60.6,
#    'end': 65.6,
#    'text': ' Men en fullvöxel man borde skjutas.',
#    'tokens': [6685,
#     465,
#     1577,
#     85,
#     973,
#     87,
#     338,
#     587,
#     272,
#     15127,
#     1110,
#     44090,
#     296,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.19817055188692534,
#    'compression_ratio': 1.2283464566929134,
#    'no_speech_prob': 5.173612407816108e-06},
#   {'id': 12,
#    'seek': 6560,
#    'start': 65.6,
#    'end': 80.6,
#    'text': ' Tack så mycket.',
#    'tokens': [50364, 38405, 4719, 16780, 13, 51114],
#    'temperature': 0.0,
#    'avg_logprob': -0.43911501339503695,
#    'compression_ratio': 0.6666666666666666,
#    'no_speech_prob': 2.317827420483809e-05}],
#  'language': 'sv'}
